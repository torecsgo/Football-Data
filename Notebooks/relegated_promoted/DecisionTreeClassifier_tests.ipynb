# %%
import pandas as pd

from tqdm import tqdm

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv('./spain_df.csv')
df.drop(columns=["Unnamed: 0"], inplace=True)
#df = df[df['tier'] == 1]
df
# Out:
#      year country   league  tier                    team  position  \
# 0    2005      ES   LaLiga     1            FC Barcelona       1.0
# 1    2005      ES   LaLiga     1             Real Madrid       2.0
# 2    2005      ES   LaLiga     1             Valencia CF       3.0
# 3    2005      ES   LaLiga     1      Atlético de Madrid      10.0
# 4    2005      ES   LaLiga     1  Deportivo de La Coruña       8.0
# ..    ...     ...      ...   ...                     ...       ...
# 793  2023      ES  LaLiga2     2           Racing Ferrol      10.0
# 794  2023      ES  LaLiga2     2            FC Cartagena      14.0
# 795  2023      ES  LaLiga2     2              CD Eldense      16.0
# 796  2023      ES  LaLiga2     2           SD Amorebieta      19.0
# 797  2023      ES  LaLiga2     2             AD Alcorcón      20.0
#
#      squad_depth  avg_age  foreigners  avg_market_value  market_value  \
# 0             34     25.4          16           9630000     327500000
# 1             36     25.4          13           7820000     281600000
# 2             34     27.3          14           6280000     213550000
# 3             31     24.2           8           4330000     134150000
# 4             34     27.5           8           3940000     133800000
# ..           ...      ...         ...               ...           ...
# 793           29     28.6           2            641000      18600000
# 794           42     27.4          12            369000      15500000
# 795           33     28.0           7            397000      13100000
# 796           28     27.1           6            455000      12750000
# 797           38     26.4           6            298000      11330000
#
#      has_relegated  has_promoted  has_won_titles  will_promote  will_relegate
# 0            False         False            True         False          False
# 1            False         False           False         False          False
# 2            False         False           False         False          False
# 3            False         False           False         False          False
# 4            False         False           False         False          False
# ..             ...           ...             ...           ...            ...
# 793          False          True           False         False          False
# 794          False         False           False         False          False
# 795          False          True           False         False          False
# 796          False          True           False         False           True
# 797          False          True           False         False           True
#
# [798 rows x 16 columns]

# %%
# Obtén los años únicos y selecciona el 80% para entrenamiento y 20% para prueba
years = df['year'].unique()
years = years[years != 2023]
years_train, years_test = train_test_split(years, test_size=0.2, random_state=42)

# Filtra los datos para crear los conjuntos de entrenamiento y prueba
train_data = df[df['year'].isin(years_train)]
test_data = df[df['year'].isin(years_test)]

# Divide las características y la variable objetivo
X_train = train_data.drop(columns=['country', 'league', 'team', 'position', 'will_promote', 'will_relegate'])
y_train = train_data['will_relegate']

X_test = test_data.drop(columns=['country', 'league', 'team', 'position', 'will_promote', 'will_relegate'])
y_test = test_data['will_relegate']


# Comprueba la distribución de años
print("Años en entrenamiento:", years_train)
print("Años en prueba:", years_test)
# Out:
# Años en entrenamiento: [2008 2018 2021 2020 2016 2007 2014 2022 2009 2017 2012 2015 2019 2011]
# Años en prueba: [2005 2006 2013 2010]

# %%
criterios = ['gini', 'entropy', 'log_loss']
profundidades = [3, 5, 10, 15, 25, 50]
estimators = [10, 20, 25, 50, 100]
mejor_clf = {'profundidad':'',
              'criterio':'',
              'estimator': '',
              'pesos_personalizados': '',
              'accuracy':'',
              'precision':'',
              'recall':'',
              'f1':''}
mejor_f1 = 0

# Asignamos un peso mayor para la clase 'False' y un peso menor para la clase 'True'
pesos_personalizados = ['balanced_subsample', 'balanced', {0: 1, 1: 5}, {0: 1, 1: 10}]

# %%
for criterio in tqdm(criterios):
    for estimator in estimators:
        for profundidad in profundidades:
            for peso in pesos_personalizados:

                # Crear el modelo de RandomForest
                rfc = RandomForestClassifier(n_estimators=estimator, criterion=criterio, max_depth=profundidad, random_state=1337, class_weight=peso)
                rfc.fit(X_train, y_train)
                predicciones = rfc.predict(X_test)
                
                # Calcular las métricas
                acc = accuracy_score(y_test, predicciones)
                prec = precision_score(y_test, predicciones)
                rec = recall_score(y_test, predicciones)
                f1 = f1_score(y_test, predicciones)

                if f1 >= mejor_f1:
                    mejor_f1 = f1
                    mejor_clf['profundidad'] = profundidad
                    mejor_clf['criterio'] = criterio
                    mejor_clf['estimator'] = estimator
                    mejor_clf['pesos_personalizados'] = peso
                    mejor_clf['accuracy'] = acc
                    mejor_clf['precision'] = prec
                    mejor_clf['recall'] = rec
                    mejor_clf['f1'] = f1
# Out:
# 100%|██████████| 3/3 [00:18<00:00,  6.29s/it]

# %%
mejor_clf
# Out:
# {'profundidad': 5,
#  'criterio': 'log_loss',
#  'estimator': 25,
#  'pesos_personalizados': 'balanced_subsample',
#  'accuracy': 0.6845238095238095,
#  'precision': np.float64(0.32857142857142857),
#  'recall': np.float64(0.7931034482758621),
#  'f1': np.float64(0.46464646464646464)}

# %%
rfc = RandomForestClassifier(n_estimators=mejor_clf['estimator'], criterion=mejor_clf['criterio'], max_depth=mejor_clf['profundidad'], random_state=1337, class_weight=mejor_clf['pesos_personalizados'])
rfc
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', criterion='log_loss',
#                        max_depth=5, n_estimators=25, random_state=1337)

# %%
rfc.fit(X_train, y_train)
predicciones = rfc.predict(X_test)

# %%
report = classification_report(y_test, predicciones, output_dict=True)
report_df = pd.DataFrame(report).transpose()
print(report_df[['precision', 'recall', 'f1-score', 'support']])
# Out:
#               precision    recall  f1-score     support
# False          0.938776  0.661871  0.776371  139.000000
# True           0.328571  0.793103  0.464646   29.000000
# accuracy       0.684524  0.684524  0.684524    0.684524
# macro avg      0.633673  0.727487  0.620509  168.000000
# weighted avg   0.833443  0.684524  0.722562  168.000000

# %%
nuevo_df = pd.read_csv('./spain_df.csv')
nuevo_df.drop(columns=["Unnamed: 0"], inplace=True)
nuevo_df = nuevo_df[nuevo_df['tier'] == 1]
predict_df = nuevo_df.drop(columns=['country', 'league', 'team', 'position', 'will_promote', 'will_relegate'])
predict_df = predict_df[predict_df['year'] == 2023]

predict_df
# Out:
#      year  tier  squad_depth  avg_age  foreigners  avg_market_value  \
# 360  2023     1           37     25.6          21          30680000
# 361  2023     1           38     24.0          15          24110000
# 362  2023     1           40     25.2          10          12460000
# 363  2023     1           42     26.9          23          10920000
# 364  2023     1           37     25.6          15           8050000
# 365  2023     1           31     27.0           2           9540000
# 366  2023     1           39     27.2          15           6470000
# 367  2023     1           36     23.8          11           6800000
# 368  2023     1           49     26.7          27           4670000
# 369  2023     1           42     27.0          21           5350000
# 370  2023     1           39     25.9          14           3830000
# 371  2023     1           46     26.4          18           3070000
# 372  2023     1           40     25.7          18           3330000
# 373  2023     1           41     24.5          15           3020000
# 374  2023     1           35     26.2          10           3210000
# 375  2023     1           32     27.2           5           3290000
# 376  2023     1           41     25.3          23           2420000
# 377  2023     1           35     26.9          14           2510000
# 378  2023     1           30     28.9          12           2130000
# 379  2023     1           44     27.0          15           1380000
#
#      market_value  has_relegated  has_promoted  has_won_titles
# 360    1140000000          False         False            True
# 361     916200000          False         False            True
# 362     498500000          False         False           False
# 363     458450000          False         False           False
# 364     297900000          False         False           False
# 365     295650000          False         False           False
# 366     252500000          False         False           False
# 367     244730000          False         False           False
# 368     228750000          False         False            True
# 369     224880000          False         False           False
# 370     149300000          False         False           False
# 371     141100000          False          True            True
# 372     133000000          False         False           False
# 373     123700000          False          True           False
# 374     112400000          False          True           False
# 375     105350000          False         False           False
# 376      99400000          False         False           False
# 377      87700000          False         False           False
# 378      63950000          False         False           False
# 379      60700000          False         False           False

# %%
predicciones_nuevo_df = rfc.predict(predict_df)
probs = rfc.predict_proba(predict_df)
probs_descender = probs[:, 1]

# Add 'team' and 'position' to nuevo_df (if needed, you can keep them for the final prediction)
predict_df['team'] = nuevo_df['team']
predict_df['position'] = nuevo_df['position']

# Add the predictions to the DataFrame
predict_df['predicciones'] = predicciones_nuevo_df
predict_df['probabilidades'] = probs_descender

# %%
predict_df.sort_values(by='position')
# Out:
#      year  tier  squad_depth  avg_age  foreigners  avg_market_value  \
# 360  2023     1           37     25.6          21          30680000
# 361  2023     1           38     24.0          15          24110000
# 364  2023     1           37     25.6          15           8050000
# 363  2023     1           42     26.9          23          10920000
# 365  2023     1           31     27.0           2           9540000
# 362  2023     1           40     25.2          10          12460000
# 369  2023     1           42     27.0          21           5350000
# 366  2023     1           39     27.2          15           6470000
# 367  2023     1           36     23.8          11           6800000
# 373  2023     1           41     24.5          15           3020000
# 375  2023     1           32     27.2           5           3290000
# 372  2023     1           40     25.7          18           3330000
# 368  2023     1           49     26.7          27           4670000
# 370  2023     1           39     25.9          14           3830000
# 377  2023     1           35     26.9          14           2510000
# 374  2023     1           35     26.2          10           3210000
# 378  2023     1           30     28.9          12           2130000
# 379  2023     1           44     27.0          15           1380000
# 376  2023     1           41     25.3          23           2420000
# 371  2023     1           46     26.4          18           3070000
#
#      market_value  has_relegated  has_promoted  has_won_titles  \
# 360    1140000000          False         False            True
# 361     916200000          False         False            True
# 364     297900000          False         False           False
# 363     458450000          False         False           False
# 365     295650000          False         False           False
# 362     498500000          False         False           False
# 369     224880000          False         False           False
# 366     252500000          False         False           False
# 367     244730000          False         False           False
# 373     123700000          False          True           False
# 375     105350000          False         False           False
# 372     133000000          False         False           False
# 368     228750000          False         False            True
# 370     149300000          False         False           False
# 377      87700000          False         False           False
# 374     112400000          False          True           False
# 378      63950000          False         False           False
# 379      60700000          False         False           False
# 376      99400000          False         False           False
# 371     141100000          False          True            True
#
#                     team  position  predicciones  probabilidades
# 360          Real Madrid       1.0         False        0.000000
# 361         FC Barcelona       2.0         False        0.000000
# 364            Girona FC       3.0         False        0.000000
# 363   Atlético de Madrid       4.0         False        0.000000
# 365      Athletic Bilbao       5.0         False        0.003910
# 362        Real Sociedad       6.0         False        0.000000
# 369  Real Betis Balompié       7.0         False        0.000000
# 366        Villarreal CF       8.0         False        0.000000
# 367          Valencia CF       9.0         False        0.000000
# 373     Deportivo Alavés      10.0         False        0.451020
# 375           CA Osasuna      11.0         False        0.269004
# 372            Getafe CF      12.0          True        0.523984
# 368           Sevilla FC      13.0         False        0.033153
# 370        Celta de Vigo      14.0         False        0.431376
# 377         RCD Mallorca      15.0          True        0.578806
# 374        UD Las Palmas      16.0          True        0.508235
# 378       Rayo Vallecano      17.0         False        0.360090
# 379             Cádiz CF      18.0          True        0.662198
# 376           UD Almería      19.0         False        0.470979
# 371           Granada CF      20.0         False        0.450175
